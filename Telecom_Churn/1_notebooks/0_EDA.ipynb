# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing data

# %%
train = pd.read_csv('../0_sql_container/datasets/train.csv')
validation = pd.read_csv('../0_sql_container/datasets/validation.csv')
test = pd.read_csv('../0_sql_container/datasets/test.csv')

# %% [markdown]
# ## Data type

# %% [markdown]
# ### String Variable Analysis

# %%
print(train.select_dtypes(include=object).columns)
# Out:
# Index(['Churn Category', 'Churn Reason', 'City', 'Contract', 'Country',
#        'Customer ID', 'Customer Status', 'Gender', 'Internet Type', 'Lat Long',
#        'Offer', 'Payment Method', 'Quarter', 'State'],
#       dtype='object')

# %%
train.select_dtypes(include=object).head(5)
# Out:
#     Churn Category         Churn Reason          City        Contract  \
# 0              NaN                  NaN     San Mateo        Two Year
# 1              NaN                  NaN  Sutter Creek  Month-to-Month
# 2              NaN                  NaN    Santa Cruz  Month-to-Month
# 3              NaN                  NaN          Brea        One Year
# 4  Dissatisfaction  Network reliability      San Jose        One Year
#
#          Country Customer ID Customer Status  Gender Internet Type  \
# 0  United States  4526-ZJJTM          Stayed  Female   Fiber Optic
# 1  United States  5302-BDJNT          Stayed    Male   Fiber Optic
# 2  United States  5468-BPMMO          Stayed    Male           NaN
# 3  United States  2212-LYASK          Stayed    Male           DSL
# 4  United States  0378-XSZPU         Churned    Male         Cable
#
#                  Lat Long    Offer   Payment Method Quarter       State
# 0  37.538309, -122.305109      NaN  Bank Withdrawal      Q3  California
# 1   38.432145, -120.77069      NaN  Bank Withdrawal      Q3  California
# 2  37.007882, -122.065975      NaN  Bank Withdrawal      Q3  California
# 3   33.924143, -117.79387      NaN      Credit Card      Q3  California
# 4  37.311088, -121.961786  Offer B      Credit Card      Q3  California

# %% [markdown]
# Looking at the string variables, I have some interesting questions:
# 1. What is churn main reason?
# 2. What are the main cities the company covers?
# 3. Does the company work only in USA?
# 4. Do we have locations with higher customer churn?
# 5. What is the most popular contract?
# 6. Do we have more female or male customers?
# 7. What is our main internet product?
# 8. How is the churn by product?
# 9. What is the most popular payment method over time?
# 10. Is there a relation between churn and payment method?

# %%
print('Churn main reason: ','\n',train['Churn Category'].value_counts(), '\n')

print('Churn detailed reason: ','\n',train.groupby('Churn Category')['Churn Reason'].value_counts())
# Out:
# Churn main reason:
#  Churn Category
# Competitor         486
# Attitude           200
# Dissatisfaction    171
# Other              134
# Price              130
# Name: count, dtype: int64
#
# Churn detailed reason:
#  Churn Category   Churn Reason
# Attitude         Attitude of support person                   136
#                  Attitude of service provider                  64
# Competitor       Competitor had better devices                188
#                  Competitor made better offer                 187
#                  Competitor offered more data                  57
#                  Competitor offered higher download speeds     54
# Dissatisfaction  Network reliability                           46
#                  Product dissatisfaction                       42
#                  Service dissatisfaction                       32
#                  Limited range of services                     25
#                  Lack of self-service on Website               17
#                  Poor expertise of online support               5
#                  Poor expertise of phone support                4
# Other            Don't know                                    87
#                  Moved                                         32
#                  Poor expertise of online support               9
#                  Deceased                                       6
# Price            Price too high                                44
#                  Long distance charges                         39
#                  Extra data charges                            27
#                  Lack of affordable download/upload speed      20
# Name: count, dtype: int64

# %% [markdown]
# As expected, the main churn reason is due to competitors, specifically better devices and offers. It makes sense considering Telecom industry, where products are relatively the same. My bets are the costumer service would play an important role on making this company different and keeping clients. But when we look into the second reson for churn, 'attitude' is also there.

# %%
## make a sql lite entry to filter cities with 'customer status' = stayed

# %%
## make a sql lite entry to filter contries with 'customer status' = stayed

# %%
train[['Contract','Customer Status']].value_counts()
# Out:
# Contract        Customer Status
# Two Year        Stayed             1088
# Month-to-Month  Churned             997
#                 Stayed              947
# One Year        Stayed              797
# Month-to-Month  Joined              249
# One Year        Churned              97
# Two Year        Churned              27
#                 Joined               13
# One Year        Joined               10
# Name: count, dtype: int64

# %% [markdown]
# 5. What is the most popular contract?
# 6. Do we have more female or male customers?
# 7. What is our main internet product?
# 8. How is the churn by product?
# 9. What is the most popular payment method over time?
# 10. Is there a relation between churn and payment method?

# %% [markdown]
# ### Numeric Variable Analysis

# %%
print(train.select_dtypes(include=np.number).columns)
# Out:
# Index(['Age', 'Avg Monthly GB Download', 'Avg Monthly Long Distance Charges',
#        'Churn Score', 'CLTV', 'Dependents', 'Device Protection Plan',
#        'Internet Service', 'Latitude', 'Longitude', 'Married',
#        'Monthly Charge', 'Multiple Lines', 'Number of Dependents',
#        'Number of Referrals', 'Online Backup', 'Online Security',
#        'Paperless Billing', 'Partner', 'Phone Service', 'Population',
#        'Premium Tech Support', 'Referred a Friend', 'Satisfaction Score',
#        'Senior Citizen', 'Streaming Movies', 'Streaming Music', 'Streaming TV',
#        'Tenure in Months', 'Total Charges', 'Total Extra Data Charges',
#        'Total Long Distance Charges', 'Total Refunds', 'Total Revenue',
#        'Under 30', 'Unlimited Data', 'Zip Code', 'Churn'],
#       dtype='object')

# %% [markdown]
# ###

# %%
train.select_dtypes(include=np.number).head(5)
# Out:
#    Age  Avg Monthly GB Download  Avg Monthly Long Distance Charges  \
# 0   72                        4                              19.44
# 1   27                       59                              45.62
# 2   59                        0                              16.07
# 3   25                       27                               0.00
# 4   31                       21                              17.22
#
#    Churn Score  CLTV  Dependents  Device Protection Plan  Internet Service  \
# 0           51  4849           0                       1                 1
# 1           27  3715           0                       1                 1
# 2           59  5092           0                       0                 0
# 3           49  2068           0                       1                 1
# 4           88  4026           0                       1                 1
#
#     Latitude   Longitude  ...  Tenure in Months  Total Charges  \
# 0  37.538309 -122.305109  ...                25        2191.15
# 1  38.432145 -120.770690  ...                35        3418.20
# 2  37.007882 -122.065975  ...                46         851.20
# 3  33.924143 -117.793870  ...                27        1246.40
# 4  37.311088 -121.961786  ...                58        3563.80
#
#    Total Extra Data Charges  Total Long Distance Charges  Total Refunds  \
# 0                         0                       486.00            0.0
# 1                         0                      1596.70            0.0
# 2                         0                       739.22            0.0
# 3                        30                         0.00            0.0
# 4                         0                       998.76            0.0
#
#    Total Revenue  Under 30  Unlimited Data  Zip Code  Churn
# 0        2677.15         0               1     94403      0
# 1        5014.90         1               1     95685      0
# 2        1590.42         0               0     95064      0
# 3        1276.40         1               0     92823      0
# 4        4562.56         0               1     95117      1
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Null values

# %% [markdown]
# ## Statistics

# %% [markdown]
# In this section I'll explore datasets basic statistics. This means I'll look into their distribution to see how the variables behave and presence of outliers.
# - Statistics (mean, outliers, boxplot, correlation)

# %%
round(train.describe(exclude=[object]),2)
# Out:
#            Age  Avg Monthly GB Download  Avg Monthly Long Distance Charges  \
# count  4225.00                  4225.00                            4225.00
# mean     46.45                    20.74                              22.77
# std      16.73                    20.37                              15.43
# min      19.00                     0.00                               0.00
# 25%      32.00                     4.00                               9.05
# 50%      46.00                    17.00                              22.57
# 75%      60.00                    27.00                              36.17
# max      80.00                    85.00                              49.99
#
#        Churn Score     CLTV  Dependents  Device Protection Plan  \
# count      4225.00  4225.00     4225.00                 4225.00
# mean         58.28  4409.75        0.23                    0.35
# std          21.20  1170.60        0.42                    0.48
# min           5.00  2003.00        0.00                    0.00
# 25%          40.00  3493.00        0.00                    0.00
# 50%          61.00  4531.00        0.00                    0.00
# 75%          75.00  5381.00        0.00                    1.00
# max          96.00  6500.00        1.00                    1.00
#
#        Internet Service  Latitude  Longitude  ...  Tenure in Months  \
# count           4225.00   4225.00    4225.00  ...           4225.00
# mean               0.79     36.21    -119.77  ...             32.68
# std                0.41      2.47       2.15  ...             24.62
# min                0.00     32.56    -124.30  ...              1.00
# 25%                1.00     33.99    -121.79  ...              9.00
# 50%                1.00     36.21    -119.62  ...             30.00
# 75%                1.00     38.20    -117.99  ...             56.00
# max                1.00     41.96    -114.19  ...             72.00
#
#        Total Charges  Total Extra Data Charges  Total Long Distance Charges  \
# count        4225.00                   4225.00                      4225.00
# mean         2306.08                      6.97                       754.72
# std          2271.45                     25.25                       854.91
# min            18.80                      0.00                         0.00
# 25%           401.50                      0.00                        67.68
# 50%          1424.60                      0.00                       396.64
# 75%          3846.75                      0.00                      1200.00
# max          8672.45                    150.00                      3564.00
#
#        Total Refunds  Total Revenue  Under 30  Unlimited Data  Zip Code  \
# count        4225.00        4225.00    4225.0         4225.00   4225.00
# mean            1.95        3065.81       0.2            0.68  93491.89
# std             7.81        2884.82       0.4            0.47   1863.34
# min             0.00          21.36       0.0            0.00  90001.00
# 25%             0.00         592.75       0.0            0.00  92102.00
# 50%             0.00        2151.47       0.0            1.00  93513.00
# 75%             0.00        4845.75       0.0            1.00  95337.00
# max            49.79       11979.34       1.0            1.00  96150.00
#
#          Churn
# count  4225.00
# mean      0.27
# std       0.44
# min       0.00
# 25%       0.00
# 50%       0.00
# 75%       1.00
# max       1.00
#
# [8 rows x 38 columns]

# %%
train.head()
# Out:
#    Age  Avg Monthly GB Download  Avg Monthly Long Distance Charges  \
# 0   72                        4                              19.44
# 1   27                       59                              45.62
# 2   59                        0                              16.07
# 3   25                       27                               0.00
# 4   31                       21                              17.22
#
#     Churn Category         Churn Reason  Churn Score          City  CLTV  \
# 0              NaN                  NaN           51     San Mateo  4849
# 1              NaN                  NaN           27  Sutter Creek  3715
# 2              NaN                  NaN           59    Santa Cruz  5092
# 3              NaN                  NaN           49          Brea  2068
# 4  Dissatisfaction  Network reliability           88      San Jose  4026
#
#          Contract        Country  ... Tenure in Months Total Charges  \
# 0        Two Year  United States  ...               25       2191.15
# 1  Month-to-Month  United States  ...               35       3418.20
# 2  Month-to-Month  United States  ...               46        851.20
# 3        One Year  United States  ...               27       1246.40
# 4        One Year  United States  ...               58       3563.80
#
#    Total Extra Data Charges  Total Long Distance Charges Total Refunds  \
# 0                         0                       486.00           0.0
# 1                         0                      1596.70           0.0
# 2                         0                       739.22           0.0
# 3                        30                         0.00           0.0
# 4                         0                       998.76           0.0
#
#    Total Revenue Under 30 Unlimited Data  Zip Code  Churn
# 0        2677.15        0              1     94403      0
# 1        5014.90        1              1     95685      0
# 2        1590.42        0              0     95064      0
# 3        1276.40        1              0     92823      0
# 4        4562.56        0              1     95117      1
#
# [5 rows x 52 columns]
